# %%
#imporint the necessary libary
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df_food=pd.read_excel("D:/Resturant_bill/Participants_Data_Final_Data_Train.xlsx")

# %% [markdown]
# # Attributes:
#
# TITLE: The feature of the restaurant which can help identify what and for whom it is suitable for.
#
# RESTAURANT_ID: A unique ID for each restaurant.
#
# CUISINES: The variety of cuisines that the restaurant offers.
#
# TIME: The open hours of the restaurant.
#
# CITY: The city in which the restaurant is located.
#
# LOCALITY: The locality of the restaurant.
#
# RATING: The average rating of the restaurant by customers.
#
# VOTES: The overall votes received by the restaurant.
#
# COST: The average cost of a two-person meal.

# %%
df_food
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 12685        QUICK BITES          13228
# 12686  CASUAL DINING,BAR           9686
# 12687             LOUNGE          11133
# 12688      CASUAL DINING           6134
# 12689      CASUAL DINING           6430
#
#                                                CUISINES  \
# 0                           Malwani, Goan, North Indian
# 1                        Asian, Modern Indian, Japanese
# 2            North Indian, Chinese, Biryani, Hyderabadi
# 3                                      Tibetan, Chinese
# 4                                              Desserts
# ...                                                 ...
# 12685                       North Indian, Burger, Kebab
# ...

# %%
#checking the shape of new dataset
df_food.shape
# Out:
# (12690, 9)

# %%
#checking the columns of dataset
df_food.columns
# Out:
# Index(['TITLE', 'RESTAURANT_ID', 'CUISINES', 'TIME', 'CITY', 'LOCALITY',
#        'RATING', 'VOTES', 'COST'],
#       dtype='object')

# %%
#checking the dtypesof the dataset
df_food.dtypes
# Out:
# TITLE            object
# RESTAURANT_ID     int64
# CUISINES         object
# TIME             object
# CITY             object
# LOCALITY         object
# RATING           object
# VOTES            object
# COST              int64
# dtype: object

# %% [markdown]
# Observation:
#
#     ►In this data set we have 2 types of data Numeric and Objective
#
#     ►Numeric belongs to Int and Float.

# %%
C1=[]
C2=[]
C3=[]
C4=[]
C5=[]
C6=[]
C7=[]
C8=[]
C9=[]
for i in range(len(df_food["CUISINES"])):
    F1=df_food["CUISINES"].iloc[i].split(",")
    try:
        C1.append(F1[0].strp())
    except:
        C1.append("NONE")
    try:
        C2.append(F1[1].strip())
    except:
        C2.append("NONE")
    try:
        C3.append(F1[2].strip())
    except:
        C3.append("NONE")
    try:
        C4.append(F1[3].strip())
    except:
        C4.append("NONE")
    try:
        C5.append(F1[4].strip())
    except:
        C5.append("NONE")
    try:
        C6.append(F1[5].strip())
    except:
        C6.append("NONE")
    try:
        C7.append(F1[6].strip())
    except:
        C7.append("NONE")
    try:
        C8.append(F1[7].strip())
    except:
        C8.append("NONE")
    try:
        C9.append(F1[8].strip())
    except:
        C9.append("NONE")

# %%
df_food["ITEM1"]=C1
df_food["ITEM2"]=C2
df_food["ITEM3"]=C3
df_food["ITEM4"]=C4
df_food["ITEM5"]=C5
df_food["ITEM6"]=C6
df_food["ITEM7"]=C7
df_food["ITEM8"]=C8
df_food["ITEM9"]=C9
df_food
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 12685        QUICK BITES          13228
# 12686  CASUAL DINING,BAR           9686
# 12687             LOUNGE          11133
# 12688      CASUAL DINING           6134
# 12689      CASUAL DINING           6430
#
#                                                CUISINES  \
# 0                           Malwani, Goan, North Indian
# 1                        Asian, Modern Indian, Japanese
# 2            North Indian, Chinese, Biryani, Hyderabadi
# 3                                      Tibetan, Chinese
# 4                                              Desserts
# ...                                                 ...
# 12685                       North Indian, Burger, Kebab
# ...

# %%
#lets make multi columns for TIME
T1=[]
T2=[]
T3=[]
for i in range(len(df_food["TIME"])):
    F2=df_food["TIME"].iloc[i].split(",")
    try:
        T1.append(F2[0].strip())
    except:
        T1.append("NoNE")
    try:
        T2.append(F2[1].strip())
    except:
        T2.append("NoNe")
    try:
        T3.append(F2[2].strip())
    except:
        T3.append("NoNe")
df_food["Time1"]=T1
df_food["Time2"]=T2
df_food["Time3"]=T3

df_food
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 12685        QUICK BITES          13228
# 12686  CASUAL DINING,BAR           9686
# 12687             LOUNGE          11133
# 12688      CASUAL DINING           6134
# 12689      CASUAL DINING           6430
#
#                                                CUISINES  \
# 0                           Malwani, Goan, North Indian
# 1                        Asian, Modern Indian, Japanese
# 2            North Indian, Chinese, Biryani, Hyderabadi
# 3                                      Tibetan, Chinese
# 4                                              Desserts
# ...                                                 ...
# 12685                       North Indian, Burger, Kebab
# ...

# %%
df_food["VOTES"]=df_food["VOTES"].str.strip("votes")

# %%
v=["(Mon-Sun)","(Mon-Fri","(Mon-Wed ","(Mon ","(Mon-Th ","(Mon-Sat"]
for i in v:
    df_food["Time1"]=df_food["Time1"].str.strip(i)

# %%
df_food["Time1"].value_counts()
# Out:
# 11am – 11pm           1499
# 12noon – 12midnigh     518
# 12noon – 11pm          467
# 11am – 12midnigh       335
# 12noon – 3:30pm        311
#                       ...
# 11:55am – 4pm            1
# 11:3am – 11:57pm         1
# 11:30am – 12:55A         1
# 3:30am – 12:30A          1
# 3:30pm – 6am             1
# Name: Time1, Length: 970, dtype: int64

# %%
v=["(Mon-Sun)","(Mon-Fri","(Mon-Wed ","(Mon ","(Mon-Th ","(Mon-Sat"]
for i in v:
    df_food["Time2"]=df_food["Time2"].str.strip(i)

# %%
df_food["Time2"].value_counts()
# Out:
# NoN                        9438
# 7pm – 11pm                  361
# u                           270
#                             172
# 6:30pm – 11pm               131
#                            ...
# 9:30am – 2pm                  1
# 1pm – 3am (Tu                 1
# 5:30pm – 3am                  1
# 7:30pm – 10pm                 1
# 11:55am – 12midnight...       1
# Name: Time2, Length: 647, dtype: int64

# %%
#lets make multiple columns for Title column
T1=[]
T2=[]
T3=[]
for i in range(len(df_food["TITLE"])):
    F2=df_food["TITLE"].iloc[i].split(",")
    try:
        T1.append(F2[0].strip())
    except:
        T1.append("NoNE")
    try:
        T2.append(F2[1].strip())
    except:
        T2.append("NoNe")
    try:
        T3.append(F2[2].strip())
    except:
        T3.append("NoNe")
df_food["Titel1"]=T1
df_food["Titel2"]=T2
df_food["Titel3"]=T3
df_food.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm – 11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am – 1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                    11am – 1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
#Lets droping the TITLE,CUISINES,TIME and RESTAURANT_ID
df_food.drop(columns=["RESTAURANT_ID","TITLE","TIME","CUISINES"],axis=1,inplace=True)
df_food.shape
# Out:
# (12690, 20)

# %%
#value counts of objectives data
c=df_food.columns
for i in c:
    if df_food[i].dtypes=='object':
        print(df_food[i].value_counts())
# Out:
# Chennai                                2174
# Bangalore                              2149
# Hyderabad                              1819
# Mumbai                                 1722
# New Delhi                              1321
#                                        ...
# Brigade Road                              1
# Phase 1 Bangalore                         1
# Vaishali Ghaziabad                        1
# Chennai (Bang Opposite Indian Bank)       1
# Vadapalani                                1
# Name: CITY, Length: 359, dtype: int64
# Gachibowli              166
# Indiranagar             138
# Edappally               122
# Kakkanad                121
# HSR                     120
#                        ...
# Rambaug                   1
# The Mylapore Cafe 29      1
# Ardee City                1
# Near Palam                1
# 5th Avenue                1
# Name: LOCALITY, Length: 1416, dtype: int64
# 3.9    1238
# 3.8    1190
# 4.0    1099
# 3.7    1086
# 3.6     951
# ...

# %% [markdown]
# # Handeling Missing Values

# %%
#checking the null values
df_food.isnull().values.any()
# Out:
# True

# %% [markdown]
# Observation:
#
#     it means we have null value in this data set

# %%
#checking null values columns wise
df_food.isnull().sum()
# Out:
# CITY         112
# LOCALITY      98
# RATING         2
# VOTES       1204
# COST           0
# ITEM1          0
# ITEM2          0
# ITEM3          0
# ITEM4          0
# ITEM5          0
# ITEM6          0
# ITEM7          0
# ITEM8          0
# ITEM9          0
# Time1          0
# Time2          0
# Time3          0
# Titel1         0
# Titel2         0
# Titel3         0
# dtype: int64

# %% [markdown]
# Observation:
#
#     ►In city columns we have 147 null values
#
#     ►similarly on Locality we have 128 null values
#
#     ►In Votes columns we have 1606 null values
#
#     ►in cost columns we have 4231 null values.

# %%
df_food.dtypes
# Out:
# CITY        object
# LOCALITY    object
# RATING      object
# VOTES       object
# COST         int64
# ITEM1       object
# ITEM2       object
# ITEM3       object
# ITEM4       object
# ITEM5       object
# ITEM6       object
# ITEM7       object
# ITEM8       object
# ITEM9       object
# Time1       object
# Time2       object
# Time3       object
# Titel1      object
# Titel2      object
# Titel3      object
# dtype: object

# %%
#for better visualization lets plot with heatmap
sns.heatmap(df_food.isnull(),cbar=False,cmap="rainbow")

# %%
#Replacing the nan value 0 and unkwon
d=df_food.columns
for f in d:
    if df_food[f].dtypes!='object':
        df_food[f].fillna(0,inplace=True)
    if df_food[f].dtypes=='object':
        df_food[f].fillna("unknown",inplace=True)

# %%
#for better visualization lets plot with heatmap
sns.heatmap(df_food.isnull(),cbar=False,cmap="rainbow")

# %% [markdown]
# Observation:
#
#     Now we can say that all null values are fill .

# %% [markdown]
# # Statistic Summary

# %%
df_food.describe()
# Out:
#                COST
# count  12690.000000
# mean     655.252246
# std      627.003540
# min       20.000000
# 25%      300.000000
# 50%      500.000000
# 75%      800.000000
# max    14000.000000

# %% [markdown]
# Observation:
#
#     minmum cost is 0
#
#     maximum cost is 14000

# %% [markdown]
# # Correlation

# %%
corr=df_food.corr()
corr
# Out:
#       COST
# COST   1.0

# %%
sns.heatmap(corr,annot=True,cmap='rainbow')

# %% [markdown]
# # Outliers

# %%
df_food.boxplot()

# %% [markdown]
# #observation:
#
#     outliers are present in cost.

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # LOCALITY

# %%
plt.figure(figsize=[12,6])
sns.countplot(x="LOCALITY",data=df_food)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # RATING

# %%
plt.figure(figsize=[12,6])
sns.countplot(x="RATING",data=df_food)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # VOTES

# %%
plt.figure(figsize=[12,6])
sns.countplot(x="VOTES",data=df_food)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # COST

# %%
plt.figure(figsize=[12,6])
sns.countplot(x="COST",data=df_food)
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# # Baivariet analysis

# %%
d=df_food.drop(['COST','VOTES','RATING','LOCALITY'],axis=1)

# %%
f=d.columns
for i in f:
    sns.violinplot(x=d[i],y='COST',data=df_food)
    plt.xlabel(i)
    plt.show()

# %% [markdown]
# # VOTE VS COST

# %%
plt.figure(figsize=[26,20])
sns.lineplot(x="VOTES",y="COST",data=df_food)
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(df_food)

# %% [markdown]
# # Handelling the categorical data

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
g=df_food.columns
for i in g:
    if df_food[i].dtypes=="object":
        df_food[i]=l.fit_transform(df_food[i])
df_food.dtypes
# Out:
# CITY        int32
# LOCALITY    int32
# RATING      int32
# VOTES       int32
# COST        int64
# ITEM1       int32
# ITEM2       int32
# ITEM3       int32
# ITEM4       int32
# ITEM5       int32
# ITEM6       int32
# ITEM7       int32
# ITEM8       int32
# ITEM9       int32
# Time1       int32
# Time2       int32
# Time3       int32
# Titel1      int32
# Titel2      int32
# Titel3      int32
# dtype: object

# %%
df_food
# Out:
#        CITY  LOCALITY  RATING  VOTES  COST  ITEM1  ITEM2  ITEM3  ITEM4  ITEM5  \
# 0       320       285      17   1278  1200      0     32     67     60     57
# 1        67      1046      23    950  1500      0     60     41     60     57
# 2        67      1101      19    712   800      0     23     12     32     57
# 3       222       136      22    787   800      0     23     64     60     57
# 4       222       620      19    470   300      0     63     64     60     57
# ...     ...       ...     ...    ...   ...    ...    ...    ...    ...    ...
# 12685   131       342      19   1349   500      0     17     44     60     57
# 12686   222       133      24    191  1800      0     25     64     60     57
# 12687   239      1342      21   1428  1300      0     25      4     18     57
# 12688    67       631      16    996   400      0     85     21     77     57
# 12689   131      1333      15   1505   600      0     23     64     60     57
#
# ...

# %%
#spliting the data into trainnig and test dataset.
df_x=df_food.drop(columns=['COST'])
y=df_food[["COST"]]
print(df_x.shape,y.shape)
# Out:
# (12690, 19) (12690, 1)

# %% [markdown]
# # FEATURE_SELECTION→

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(df_x,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(df_x.columns)

# %%
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']  #naming the dataframe columns

# %%
featureScores
# Out:
#     Features         Score
# 0       CITY   7273.491055
# 1   LOCALITY  23211.678131
# 2     RATING   2242.542272
# 3      VOTES  56312.344046
# 4      ITEM1           NaN
# 5      ITEM2   2914.417344
# 6      ITEM3   6139.480549
# 7      ITEM4   2031.019045
# 8      ITEM5    458.990088
# 9      ITEM6     44.035360
# 10     ITEM7     22.936363
# 11     ITEM8      8.369063
# 12     ITEM9           NaN
# 13     Time1  72910.875241
# 14     Time2   7893.948148
# 15     Time3    511.963990
# 16    Titel1  19251.624992
# 17    Titel2   1829.167377
# 18    Titel3           NaN

# %%
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
#     Features         Score
# 13     Time1  72910.875241
# 3      VOTES  56312.344046
# 1   LOCALITY  23211.678131
# 16    Titel1  19251.624992
# 14     Time2   7893.948148
# 0       CITY   7273.491055
# 6      ITEM3   6139.480549
# 5      ITEM2   2914.417344
# 2     RATING   2242.542272
# 7      ITEM4   2031.019045

# %%
#taking df_x_f for training
#Stamdardize the data
from sklearn.preprocessing import StandardScaler
dc=StandardScaler()
x=dc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x
# Out:
#            CITY  LOCALITY    RATING     VOTES  ITEM1     ITEM2     ITEM3  \
# 0      2.036578 -0.930612 -0.290749  0.415404    0.0 -0.645859  0.664666
# 1     -0.905207  0.954463  0.679604 -0.189195    0.0  0.517176 -0.576567
# 2     -0.905207  1.090704  0.032702 -0.627898    0.0 -1.019692 -1.961020
# 3      0.897072 -1.299700  0.517879 -0.489651    0.0 -1.019692  0.521447
# 4      0.897072 -0.100783  0.032702 -1.073974    0.0  0.641787  0.521447
# ...         ...       ...       ...       ...    ...       ...       ...
# 12685 -0.161040 -0.789417  0.032702  0.546278    0.0 -1.268913 -0.433348
# 12686  0.897072 -1.307132  0.841330 -1.588252    0.0 -0.936618  0.521447
# 12687  1.094742  1.687686  0.356153  0.691898    0.0 -0.936618 -2.342937
# 12688 -0.905207 -0.073534 -0.452475 -0.104404    0.0  1.555600 -1.531362
# 12689 -0.161040  1.665392 -0.614201  0.833831    0.0 -1.019692  0.521447
#
#           ITEM4    ITEM5     ITEM6     ITEM7     ITEM8  ITEM9     Time1  \
# ...

# %% [markdown]
# # Model Creation

# %%
#In this data set we know that out target variable COST is continuous so we are going to take Regressor Algorithms
#lets make a function for getting the best random_satae for a model toget better accuracy(r2_score)
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
def food_cost(rgr,x,y):
    max_acc=0
    for food in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=food,test_size=0.20)
        rgr.fit(x_train,y_train)
        prd=rgr.predict(x_test)
        acc=r2_score(y_test,prd)
        if acc>max_acc:
            max_acc=acc
            final_rd=food
        
    print("max r2 score coresponding to ",final_rd,"♫is♫",max_acc*100)
    print("Mean_Squared_Error is: ",mean_squared_error(y_test,prd))
    print("Mean_Absolute_Error is: ",mean_absolute_error(y_test,prd))
    print("RMSE is →",np.sqrt(mean_squared_error(y_test,prd)))
    return final_rd

# %%
#importing the linear regresson
from sklearn.linear_model import LinearRegression
lnr=LinearRegression()
food_cost(lnr,x,y)
# Out:
# max r2 score coresponding to  67 ♫is♫ 22.333579951832803
# Mean_Squared_Error is:  262715.02966243954
# Mean_Absolute_Error is:  311.17903397737933
# RMSE is → 512.5573428041389
# 67

# %%
#lets make a function for cross_val_score
from sklearn.model_selection import cross_val_score   
def k(model,x,y):
    c=cross_val_score(model,x,y,cv=5,scoring="r2")
    print("mean r2 score for ",model,c.mean())
    print("Standard deviation  in r2 score for ",model,c.std())
    print()
    print("******************************************************")
    print("After seen the cross validation score of",model,"the r2score mean is",c.mean())

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet

# %%
from sklearn.model_selection import GridSearchCV
la=Lasso()
parameters={"alpha":[0.0001,0.001,0.01,0.1,0.1]}
gl=GridSearchCV(la,parameters,cv=5,scoring="r2")
gl.fit(x,y)
gl.best_params_
# Out:
# {'alpha': 0.1}

# %%
la=Lasso(alpha=0.1)
food_cost(la,x,y)
# Out:
# max r2 score coresponding to  67 ♫is♫ 22.333772115600947
# Mean_Squared_Error is:  262711.75722147647
# Mean_Absolute_Error is:  311.1539114436914
# RMSE is → 512.5541505260459
# 67

# %%
k(la,x,y)
# Out:
# mean r2 score for  Lasso(alpha=0.1) 0.185176583029804
# Standard deviation  in r2 score for  Lasso(alpha=0.1) 0.017367800524646544
#
# ******************************************************
# After seen the cross validation score of Lasso(alpha=0.1) the r2score mean is 0.185176583029804

# %%
rd=Ridge()
parameters={"alpha":[0.0001,0.001,0.01,0.1,0.1]}
gr=GridSearchCV(rd,parameters,cv=5,scoring="r2")
gr.fit(x,y)
gr.best_params_
# Out:
# {'alpha': 0.1}

# %%
rd=Ridge(alpha=0.1)
food_cost(rd,x,y)
# Out:
# max r2 score coresponding to  67 ♫is♫ 22.333569188730962
# Mean_Squared_Error is:  262714.972587321
# Mean_Absolute_Error is:  311.17890280246513
# RMSE is → 512.557287127323
# 67

# %%
k(rd,x,y)
# Out:
# mean r2 score for  Ridge(alpha=0.1) 0.1851551459769927
# Standard deviation  in r2 score for  Ridge(alpha=0.1) 0.017341655500836863
#
# ******************************************************
# After seen the cross validation score of Ridge(alpha=0.1) the r2score mean is 0.1851551459769927

# %%
el=ElasticNet()
parameters={"alpha":[0.0001,0.001,0.01,0.1,0.1]}
ge=GridSearchCV(el,parameters,cv=5,scoring="r2")
ge.fit(x,y)
ge.best_params_
# Out:
# {'alpha': 0.1}

# %%
el=ElasticNet(alpha=0.01)
food_cost(el,x,y)
# Out:
# max r2 score coresponding to  67 ♫is♫ 22.32781654811341
# Mean_Squared_Error is:  262687.2846224735
# Mean_Absolute_Error is:  311.1145306638317
# RMSE is → 512.5302767861364
# 67

# %%
k(el,x,y)
# Out:
# mean r2 score for  ElasticNet(alpha=0.01) 0.1851855235182379
# Standard deviation  in r2 score for  ElasticNet(alpha=0.01) 0.017356802498003695
#
# ******************************************************
# After seen the cross validation score of ElasticNet(alpha=0.01) the r2score mean is 0.1851855235182379

# %%
from sklearn.ensemble import RandomForestRegressor
rn=RandomForestRegressor(n_estimators=501)
food_cost(rn,x,y)
# Out:
# max r2 score coresponding to  74 ♫is♫ 75.98507800355081
# Mean_Squared_Error is:  95384.49988563042
# Mean_Absolute_Error is:  185.51800740770202
# RMSE is → 308.84381147374546
# 74

# %%
k(rn,x,y)
# Out:
# mean r2 score for  RandomForestRegressor(n_estimators=501) 0.6997869429529107
# Standard deviation  in r2 score for  RandomForestRegressor(n_estimators=501) 0.03720371427327169
#
# ******************************************************
# After seen the cross validation score of RandomForestRegressor(n_estimators=501) the r2score mean is 0.6997869429529107

# %%
from sklearn.tree import DecisionTreeRegressor
dc=DecisionTreeRegressor()
food_cost(dc,x,y)
# Out:
# max r2 score coresponding to  56 ♫is♫ 56.26480199834383
# Mean_Squared_Error is:  178514.85421591805
# Mean_Absolute_Error is:  253.69976359338062
# RMSE is → 422.51018238134577
# 56

# %%
k(dc,x,y)
# Out:
# mean r2 score for  DecisionTreeRegressor() 0.4211654077664802
# Standard deviation  in r2 score for  DecisionTreeRegressor() 0.07880443369477431
#
# ******************************************************
# After seen the cross validation score of DecisionTreeRegressor() the r2score mean is 0.4211654077664802

# %%
from sklearn.neighbors import KNeighborsRegressor
kn=KNeighborsRegressor(n_neighbors=49)
food_cost(kn,x,y)
# Out:
# max r2 score coresponding to  76 ♫is♫ 32.891564068062095
# Mean_Squared_Error is:  240256.95599055948
# Mean_Absolute_Error is:  285.6101059809267
# RMSE is → 490.160133008142
# 76

# %%
k(kn,x,y)
# Out:
# mean r2 score for  KNeighborsRegressor(n_neighbors=49) 0.2962366680885521
# Standard deviation  in r2 score for  KNeighborsRegressor(n_neighbors=49) 0.017952488303884927
#
# ******************************************************
# After seen the cross validation score of KNeighborsRegressor(n_neighbors=49) the r2score mean is 0.2962366680885521

# %%
from sklearn.svm import SVR
s=SVR()
food_cost(s,x,y)
# Out:
# max r2 score coresponding to  95 ♫is♫ 6.865378125595035
# Mean_Squared_Error is:  315292.1728082214
# Mean_Absolute_Error is:  302.5709907249041
# RMSE is → 561.5088359128656
# 95

# %%
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor,ExtraTreesRegressor

# %%
gr=GradientBoostingRegressor(n_estimators=501)
food_cost(gr,x,y)
# Out:
# max r2 score coresponding to  94 ♫is♫ 76.56553944711848
# Mean_Squared_Error is:  102786.64485345675
# Mean_Absolute_Error is:  190.20893948071034
# RMSE is → 320.60356338234413
# 94

# %%
k(gr,x,y)
# Out:
# mean r2 score for  GradientBoostingRegressor(n_estimators=501) 0.7197128269049075
# Standard deviation  in r2 score for  GradientBoostingRegressor(n_estimators=501) 0.03704239540042763
#
# ******************************************************
# After seen the cross validation score of GradientBoostingRegressor(n_estimators=501) the r2score mean is 0.7197128269049075

# %%
ad=AdaBoostRegressor()
food_cost(ad,x,y)
# Out:
# max r2 score coresponding to  80 ♫is♫ 7.5465632009173
# Mean_Squared_Error is:  499786.0945441616
# Mean_Absolute_Error is:  611.30731912264
# RMSE is → 706.9555110077024
# 80

# %%
k(ad,x,y)
# Out:
# mean r2 score for  AdaBoostRegressor() -0.572947706622883
# Standard deviation  in r2 score for  AdaBoostRegressor() 0.3838068823166615
#
# ******************************************************
# After seen the cross validation score of AdaBoostRegressor() the r2score mean is -0.572947706622883

# %%
ext=ExtraTreesRegressor()
food_cost(ext,x,y)
# Out:
# max r2 score coresponding to  94 ♫is♫ 75.62206571484673
# Mean_Squared_Error is:  96646.80398707643
# Mean_Absolute_Error is:  188.72223010244286
# RMSE is → 310.8806909202893
# 94

# %%
k(ext,x,y)
# Out:
# mean r2 score for  ExtraTreesRegressor() 0.7101047490287766
# Standard deviation  in r2 score for  ExtraTreesRegressor() 0.04534540400984499
#
# ******************************************************
# After seen the cross validation score of ExtraTreesRegressor() the r2score mean is 0.7101047490287766

# %%
from xgboost import XGBRegressor
xgb=XGBRegressor()
food_cost(xgb,x,y)
# Out:
# max r2 score coresponding to  79 ♫is♫ 76.19065433396453
# Mean_Squared_Error is:  95573.96116768385
# Mean_Absolute_Error is:  187.88732678914653
# RMSE is → 309.1503860060405
# 79

# %%
k(xgb,x,y)
# Out:
# mean r2 score for  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None) 0.7271307835545435
# Standard deviation  in r2 score for  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
# ...

# %%
from lightgbm import LGBMRegressor

# %%
lgb=LGBMRegressor()
food_cost(lgb,x,y)
# Out:
# max r2 score coresponding to  94 ♫is♫ 76.70109168300615
# Mean_Squared_Error is:  93520.66450147744
# Mean_Absolute_Error is:  182.11181016620895
# RMSE is → 305.81148523473973
# 94

# %%
k(lgb,x,y)
# Out:
# mean r2 score for  LGBMRegressor() 0.7314299333692903
# Standard deviation  in r2 score for  LGBMRegressor() 0.04402166956791925
#
# ******************************************************
# After seen the cross validation score of LGBMRegressor() the r2score mean is 0.7314299333692903

# %%
#after seen the above results  i am going to finalise my model withLGBMRegressor(),because this is performing well in this dataset
#RMSE also low from other model
#with the random sate of 94 
lgb=LGBMRegressor()
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=94,test_size=0.20)
lgb.fit(x_train,y_train)
prd=lgb.predict(x_test)
accuracy=r2_score(y_test,prd)
print("accuracy",accuracy*100)
print('\n')
print('\n')
print("Mean_Squared_Error is: ",mean_squared_error(y_test,prd))
print('\n')
print("Mean_Absolute_Error is: ",mean_absolute_error(y_test,prd))
print('\n')
print("RMSE is →",np.sqrt(mean_squared_error(y_test,prd)))
# Out:
# accuracy 76.70109168300615
#
#
#
#
# Mean_Squared_Error is:  80985.6815867743
#
#
# Mean_Absolute_Error is:  176.344629228337
#
#
# RMSE is → 284.5798334154659

# %%
import joblib #importing the job
  
# Save the model as a pickle in a file 
joblib.dump(lgb,'food_cost.pkl')
# Out:
# ['food_cost.pkl']

# %%
#saving the predict as csv
joblib.dump(lnr,'food_cost.csv')
# Out:
# ['food_cost.csv']

# %%
#lets call the model and predict it
model=joblib.load('food_cost.csv')
model.predict(x_test)
# Out:
# array([[1115.34120584],
#        [ 425.34824055],
#        [ 335.63550237],
#        ...,
#        [ 351.58633926],
#        [ 514.46347322],
#        [ 409.60041052]])
